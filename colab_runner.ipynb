# %% [markdown]
# # 🧠 Research Paper Intelligence Engine - Google Colab Runner
#
# This notebook allows you to run the Streamlit app on a free Google Colab GPU, making model inference lightning fast!
#
# ### Step 1: Upload your files
# Upload `app.py`, `config.py`, `requirements.txt` and the `src/` folder to the Colab environment using the file browser on the left.

# %%
# Install dependencies (this takes ~1-2 minutes)
# !pip install -r requirements.txt
# !npm install localtunnel

# %% [markdown]
# ### Step 2: Get your endpoint IP
# Run the cell below. It will print an IP address. **Copy this IP address** because you will need to paste it into the localtunnel website in the next step to authenticate your session.

# %%
import urllib
print("Password/Endpoint IP for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip())

# %% [markdown]
# ### Step 3: Launch the App
# Run the cell below. It will output a `loca.lt` URL. Click that link, paste the IP address from Step 2 into the warning page, and your Streamlit app will load!

# %%
# !streamlit run app.py &>/content/logs.txt & npx localtunnel --port 8501
